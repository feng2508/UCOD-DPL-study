# %%
# !find /kaggle/input -maxdepth 4 -type d
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/wenfengk
# /kaggle/input/datasets/wenfengk/ucod-dpl-code
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/configs
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/weights
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/models
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/images
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/engine
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/data
# /kaggle/input/datasets/wenfengk/ucod-dpl-refcod-dataset
# /kaggle/input/datasets/wenfengk/ucod-dpl-refcod-dataset/datasets

# %%
# !find /kaggle/input -maxdepth 5 -type f | head -100
# Out:
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/requirement.txt
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/train.py
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/launch_train_first_stage.sh
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/launch_val_second_stage.sh
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/launch_val_first_stage.sh
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/LTeval.py
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/eval.py
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/LTtrain.py
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/args.py
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/scripts/launch_train_second_stage.sh
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/.gitignore
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/Makefile
# /kaggle/input/datasets/wenfengk/ucod-dpl-code/weights/UCOD_DPL_dinov1.safetensors
# ...

# %%
# %cd /kaggle/working/UCOD-DPL

# !pip install -q -r requirement.txt safetensors pyyaml
# Out:
# /kaggle/working/UCOD-DPL
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 103.2 MB/s eta 0:00:0000:01:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ...

# %%
# !rm -rf /kaggle/working/UCOD-DPL
# !rm -rf /kaggle/temp/UCOD-DPL
# !mkdir -p /kaggle/temp/UCOD-DPL/cache

# !cp -r /kaggle/input/datasets/wenfengk/ucod-dpl-code /kaggle/working/UCOD-DPL
# !rm -rf /kaggle/working/UCOD-DPL/datasets
# !ln -s /kaggle/input/datasets/wenfengk/ucod-dpl-refcod-dataset/datasets /kaggle/working/UCOD-DPL/datasets
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory

# %%
# !ls -lah /kaggle/working/UCOD-DPL
# !ls -lah /kaggle/working/UCOD-DPL/datasets
# !find /kaggle/working/UCOD-DPL/datasets/RefCOD -maxdepth 2 -type d | head -30
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# total 68K
# drwxr-xr-x 9 root root 4.0K May 27 06:15 .
# drwxr-xr-x 4 root root 4.0K May 27 06:15 ..
# drwxr-xr-x 5 root root 4.0K May 27 06:15 configs
# drwxr-xr-x 4 root root 4.0K May 27 06:15 data
# lrwxrwxrwx 1 root root   64 May 27 06:15 datasets -> /kaggle/input/datasets/wenfengk/ucod-dpl-refcod-dataset/datasets
# drwxr-xr-x 6 root root 4.0K May 27 06:15 engine
# -rw-r--r-- 1 root root 5.2K May 27 06:15 generate_pseudo_label.py
# -rw-r--r-- 1 root root 3.3K May 27 06:15 .gitignore
# drwxr-xr-x 2 root root 4.0K May 27 06:15 images
# -rw-r--r-- 1 root root  469 May 27 06:15 Makefile
# drwxr-xr-x 4 root root 4.0K May 27 06:15 models
# -rw-r--r-- 1 root root 5.9K May 27 06:15 README.md
# -rw-r--r-- 1 root root  101 May 27 06:15 requirement.txt
# drwxr-xr-x 2 root root 4.0K May 27 06:15 scripts
# drwxr-xr-x 2 root root 4.0K May 27 06:15 weights
# ...

# %% [markdown]
# # Run first-stage DINOv2 evaluation

# %%
# %cd /kaggle/working/UCOD-DPL
# !pwd
# !ls scripts/launch_val_first_stage.sh
# Out:
# /kaggle/working/UCOD-DPL
# /kaggle/working/UCOD-DPL
# scripts/launch_val_first_stage.sh

# %%
# !bash ./scripts/launch_val_first_stage.sh \
  -c ./configs/uscod/UCOD-DPL_dinov2.py \
  -m ./weights/UCOD_DPL_dinov2.safetensors \
  -g 1
# Out:
# accelerate launch --mixed_precision fp16 --machine_rank 0 --num_machines 1 --main_process_port 11145 --num_processes 1 scripts/eval.py --config ./configs/uscod/UCOD-DPL_dinov2.py --load_from ./weights/UCOD_DPL_dinov2.safetensors
# PYTHONPATH=./
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# ...
